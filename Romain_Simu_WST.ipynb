# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from os import listdir
import os
import sys
sys.path.insert(0, os.path.abspath('..')) # Note that this line is useless with a regular pip installation of PyWST.
import pywst as pw
# %matplotlib notebook

# %%
def read_cube(path, type = np.float):
    try :
        cube = np.fromfile(path, dtype=type)
    except FileNotFoundError :
        print(" !!!!!! file not found : "+ path)
        cube = np.zeros(256**3)
        print("moving on...")
    #print('cube loaded')
    shape = np.shape(cube)[0]
    #print( 'shape = ', shape)
    length = int(shape**(1/3)) +1

    cube =np.reshape(cube, (length,length,length)).T
    shape = np.shape(cube)
    #print('av, min, max : ',np.mean(cube), np.min(cube), np.max(cube))
    return cube
# Out:
# /tmp/ipykernel_417409/3897988224.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def read_cube(path, type = np.float):

# %% [markdown]
# # Simulation Details:
#
# Central : 13
#
# +- dMmin : 22, 4
#
# +- dfx   :  16,10
#
# +- dfesc_post :  14,12
#
#
# parameters of each sims are in simu000XX/runtime_parameters_simulation_X
#
# I chose to vary one parameter for star formation (Mmin), one for x-ray emissivity (fx), one for UV emissivit(escape fraction fesc_post)
#
# Cubes of physical quantities are in simu000XX/postprocessing/cubes
#
# They are 256*256*256 cubes. example.py shows one way of reading them
# simu000XX/postprocessing/z_dtb_tneutre_xa.txt has four columns of global quantities : redshift, global brightness temperature, average temperature of the neutral gas, lyman-alpha coupling
# These are the redshifts at which the cubes were computed.

# %%
ddir = '/obs/ihothi/Romain_data/Data/'
Folders = listdir(ddir)

# %%
simu00004 = np.zeros((4,256,256,256))
simu00010 = np.zeros((4,256,256,256))
simu00012 = np.zeros((4,256,256,256))
simu00013 = np.zeros((4,256,256,256))
simu00014 = np.zeros((4,256,256,256))
simu00016 = np.zeros((4,256,256,256))
simu00022 = np.zeros((4,256,256,256))

# %%
path_test = ddir+Folders[0]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'
data_test = read_cube(path_test)
print(data_test.shape)
plt_dir = '/obs/ihothi/WST_RWST_Figures/Romain_Benoit_Sim_Test/'

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))

im = axes.imshow( (data_test[0]) , extent = [0,294,0,294],cmap='inferno')
axes.set_xlabel('Mpc')
plt.savefig(plt_dir+'Example_Sim.eps', bbox_inches= 'tight')
# Out:
# (256, 256, 256)
# <img src="data:image/png;base64,..." width="1000">

# %%
simu00004[0,:,:,:] = read_cube(ddir+Folders[0]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00004[1,:,:,:] = read_cube(ddir+Folders[0]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00004[2,:,:,:] = read_cube(ddir+Folders[0]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00004[3,:,:,:] = read_cube(ddir+Folders[0]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00010[0,:,:,:] = read_cube(ddir+Folders[1]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00010[1,:,:,:] = read_cube(ddir+Folders[1]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00010[2,:,:,:] = read_cube(ddir+Folders[1]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00010[3,:,:,:] = read_cube(ddir+Folders[1]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00012[0,:,:,:] = read_cube(ddir+Folders[2]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00012[1,:,:,:] = read_cube(ddir+Folders[2]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00012[2,:,:,:] = read_cube(ddir+Folders[2]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00012[3,:,:,:] = read_cube(ddir+Folders[2]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00013[0,:,:,:] = read_cube(ddir+Folders[3]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00013[1,:,:,:] = read_cube(ddir+Folders[3]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00013[2,:,:,:] = read_cube(ddir+Folders[3]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00013[3,:,:,:] = read_cube(ddir+Folders[3]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00014[0,:,:,:] = read_cube(ddir+Folders[4]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00014[1,:,:,:] = read_cube(ddir+Folders[4]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00014[2,:,:,:] = read_cube(ddir+Folders[4]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00014[3,:,:,:] = read_cube(ddir+Folders[4]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00016[0,:,:,:] = read_cube(ddir+Folders[5]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00016[1,:,:,:] = read_cube(ddir+Folders[5]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00016[2,:,:,:] = read_cube(ddir+Folders[5]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00016[3,:,:,:] = read_cube(ddir+Folders[5]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
simu00022[0,:,:,:] = read_cube(ddir+Folders[6]+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00022[1,:,:,:] = read_cube(ddir+Folders[6]+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00022[2,:,:,:] = read_cube(ddir+Folders[6]+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00022[3,:,:,:] = read_cube(ddir+Folders[6]+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
M, N = 256,256 # Height and width of the test maps
J = 7 # We choose to probe 7 scales
L = 8 # Number of angles in which the interval [0,pi] is divided
OS = 0 # No oversampling

# %%
wst_op = pw.WSTOp(M, N, J, L, OS)

# %%
simu00004_WST = [wst_op.apply(i).to_log2() for i in simu00004[:,:,:,0]]

# %%
simu00010_WST = [wst_op.apply(i).to_log2() for i in simu00010[:,:,:,0]]

# %%
simu00013_WST = [wst_op.apply(i).to_log2() for i in simu00013[:,:,:,0]]

# %%
simu00012_WST = [wst_op.apply(i).to_log2() for i in simu00012[:,:,:,0]]

# %%
simu00014_WST = [wst_op.apply(i).to_log2() for i in simu00014[:,:,:,0]]

# %%
simu00016_WST = [wst_op.apply(i).to_log2() for i in simu00016[:,:,:,0]]

# %%
simu00022_WST = [wst_op.apply(i).to_log2() for i in simu00022[:,:,:,0]]

# %% [markdown]
# ## simu00004

# %%
simu00004_WST[0].plot_compare(simu00004_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00004_WST[0].plot_compare(simu00004_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## simu00010

# %%
simu00010_WST[0].plot_compare(simu00010_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00010_WST[0].plot_compare(simu00010_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## simu00012

# %%
simu00012_WST[0].plot_compare(simu00012_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00012_WST[0].plot_compare(simu00012_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## simu00014

# %%
simu00014_WST[0].plot_compare(simu00014_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00014_WST[0].plot_compare(simu00014_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## simu00016

# %%
simu00016_WST[0].plot_compare(simu00016_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00016_WST[0].plot_compare(simu00016_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## simu00022

# %%
simu00022_WST[0].plot_compare(simu00022_WST[1:],layer = 1, labels = ['10','20','30','40'])

# %%
simu00022_WST[0].plot_compare(simu00022_WST[1:],layer = 2, labels = ['10','20','30','40'])

# %% [markdown]
# ## 10

# %%
simu00004_WST[0].plot_compare([simu00010_WST[0],simu00012_WST[0],
                               simu00013_WST[0],simu00014_WST[0],simu00016_WST[0],
                              simu00022_WST[0]],layer = 1, labels = ['4','10','12','13','14','16','22'])

# %%
simu00004_WST[0].plot_compare([simu00010_WST[0],simu00012_WST[0],
                               simu00013_WST[0],simu00014_WST[0],simu00016_WST[0],
                              simu00022_WST[0]],layer = 2, labels = ['4','10','12','13','14','16','22'])

# %% [markdown]
# ## 20

# %%
simu00004_WST[1].plot_compare([simu00010_WST[1],simu00012_WST[1],
                               simu00013_WST[1],simu00014_WST[1],simu00016_WST[1],
                              simu00022_WST[1]],layer = 1, labels = ['4','10','12','13','14','16','22'])

# %%
simu00004_WST[1].plot_compare([simu00010_WST[1],simu00012_WST[1],
                               simu00013_WST[1],simu00014_WST[1],simu00016_WST[1],
                              simu00022_WST[1]],layer = 2, labels = ['4','10','12','13','14','16','22'])

# %% [markdown]
# ## 30

# %%
simu00004_WST[2].plot_compare([simu00010_WST[2],simu00012_WST[2],
                               simu00013_WST[2],simu00014_WST[2],simu00016_WST[2],
                              simu00022_WST[2]],layer = 1, labels = ['4','10','12','13','14','16','22'])

# %%
simu00004_WST[2].plot_compare([simu00010_WST[2],simu00012_WST[2],
                               simu00013_WST[2],simu00014_WST[2],simu00016_WST[2],
                              simu00022_WST[2]],layer = 2, labels = ['4','10','12','13','14','16','22'])

# %% [markdown]
# ## 40

# %%
simu00004_WST[3].plot_compare([simu00010_WST[3],simu00012_WST[3],
                               simu00013_WST[3],simu00014_WST[3],simu00016_WST[3],
                              simu00022_WST[3]],layer = 1, labels = ['4','10','12','13','14','16','22'])

# %%
simu00004_WST[3].plot_compare([simu00010_WST[3],simu00012_WST[3],
                               simu00013_WST[3],simu00014_WST[3],simu00016_WST[3],
                              simu00022_WST[3]],layer = 2, labels = ['4','10','12','13','14','16','22'])
