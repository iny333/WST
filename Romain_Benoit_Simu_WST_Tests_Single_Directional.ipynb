# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from os import listdir
import os
import sys
sys.path.insert(0, os.path.abspath('..')) # Note that this line is useless with a regular pip installation of PyWST.
import pywst as pw
# %matplotlib notebook

# %%
def read_cube(path, type = np.float):
    try :
        cube = np.fromfile(path, dtype=type)
    except FileNotFoundError :
        print(" !!!!!! file not found : "+ path)
        cube = np.zeros(256**3)
        print("moving on...")
    #print('cube loaded')
    shape = np.shape(cube)[0]
    #print( 'shape = ', shape)
    length = int(shape**(1/3)) +1

    cube =np.reshape(cube, (length,length,length)).T
    shape = np.shape(cube)
    #print('av, min, max : ',np.mean(cube), np.min(cube), np.max(cube))
    return cube
# Out:
# /Users/ianhothi/anaconda3/envs/pywst/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Simulation Details:
#
# Central : 13
#
# +- dMmin : 22, 4
#
# +- dfx   :  16,10
#
# +- dfesc_post :  14,12
#
#
# parameters of each sims are in simu000XX/runtime_parameters_simulation_X
#
# I chose to vary one parameter for star formation (Mmin), one for x-ray emissivity (fx), one for UV emissivit(escape fraction fesc_post)
#
# Cubes of physical quantities are in simu000XX/postprocessing/cubes
#
# They are 256*256*256 cubes. example.py shows one way of reading them
# simu000XX/postprocessing/z_dtb_tneutre_xa.txt has four columns of global quantities : redshift, global brightness temperature, average temperature of the neutral gas, lyman-alpha coupling
# These are the redshifts at which the cubes were computed.

# %%
ddir = '/Users/ianhothi/WST/Testing/pywst/examples/data/'
plt_dir = '/Users/ianhothi/Dropbox/WST_RWST/Figures/Romain_Benoit_Sim_Test/'
Folders = listdir(ddir)

# %%
simu00004 = np.zeros((4,256,256,256))
simu00010 = np.zeros((4,256,256,256))
simu00012 = np.zeros((4,256,256,256))
simu00013 = np.zeros((4,256,256,256))
simu00014 = np.zeros((4,256,256,256))
simu00016 = np.zeros((4,256,256,256))
simu00022 = np.zeros((4,256,256,256))

# %%
simu00004[0,:,:,:] = np.array(read_cube(ddir+'simu00004'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00004[1,:,:,:] = np.array(read_cube(ddir+'simu00004'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00004[2,:,:,:] = np.array(read_cube(ddir+'simu00004'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00004[3,:,:,:] = np.array(read_cube(ddir+'simu00004'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00010[0,:,:,:] = np.array(read_cube(ddir+'simu00010'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00010[1,:,:,:] = np.array(read_cube(ddir+'simu00010'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00010[2,:,:,:] = np.array(read_cube(ddir+'simu00010'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00010[3,:,:,:] = np.array(read_cube(ddir+'simu00010'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00012[0,:,:,:] = np.array(read_cube(ddir+'simu00012'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00012[1,:,:,:] = np.array(read_cube(ddir+'simu00012'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00012[2,:,:,:] = np.array(read_cube(ddir+'simu00012'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00012[3,:,:,:] = np.array(read_cube(ddir+'simu00012'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00013[0,:,:,:] = np.array(read_cube(ddir+'simu00013'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00013[1,:,:,:] = np.array(read_cube(ddir+'simu00013'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00013[2,:,:,:] = np.array(read_cube(ddir+'simu00013'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00013[3,:,:,:] = np.array(read_cube(ddir+'simu00013'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00014[0,:,:,:] = np.array(read_cube(ddir+'simu00014'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00014[1,:,:,:] = np.array(read_cube(ddir+'simu00014'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00014[2,:,:,:] = np.array(read_cube(ddir+'simu00014'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00014[3,:,:,:] = np.array(read_cube(ddir+'simu00014'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00016[0,:,:,:] = np.array(read_cube(ddir+'simu00016'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat'))
simu00016[1,:,:,:] = np.array(read_cube(ddir+'simu00016'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat'))
simu00016[2,:,:,:] = np.array(read_cube(ddir+'simu00016'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat'))
simu00016[3,:,:,:] = np.array(read_cube(ddir+'simu00016'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat'))

# %%
simu00022[0,:,:,:] = read_cube(ddir+'simu00022'+'/'+'dtb_tp_hi_256_nocorrection_out010.dat')
simu00022[1,:,:,:] = read_cube(ddir+'simu00022'+'/'+'dtb_tp_hi_256_nocorrection_out020.dat')
simu00022[2,:,:,:] = read_cube(ddir+'simu00022'+'/'+'dtb_tp_hi_256_nocorrection_out030.dat')
simu00022[3,:,:,:] = read_cube(ddir+'simu00022'+'/'+'dtb_tp_hi_256_nocorrection_out040.dat')

# %%
M, N = 256,256 # Height and width of the test maps
J = 7 # We choose to probe 7 scales
L = 8 # Number of angles in which the interval [0,pi] is divided
OS = 0 # No oversampling

# %%
wst_op = pw.WSTOp(M, N, J, L, OS)

# %%
simu00004_WST = [wst_op.apply(i).to_log2() for i in simu00004[:,:,:,0]]

# %%
simu00010_WST = [wst_op.apply(i).to_log2() for i in simu00010[:,:,:,0]]
# Out:
# /Users/ianhothi/anaconda3/envs/pywst/lib/python3.7/site-packages/pywst/wst.py:219: RuntimeWarning: invalid value encountered in log2
#   self.coeffs = np.log2(self.coeffs)

# %%
simu00013_WST = [wst_op.apply(i).to_log2() for i in simu00013[:,:,:,0]]

# %%
simu00012_WST = [wst_op.apply(i).to_log2() for i in simu00012[:,:,:,0]]

# %%
simu00014_WST = [wst_op.apply(i).to_log2() for i in simu00014[:,:,:,0]]

# %%
simu00016_WST = [wst_op.apply(i).to_log2() for i in simu00016[:,:,:,0]]

# %%
simu00022_WST = [wst_op.apply(i).to_log2() for i in simu00022[:,:,:,0]]

# %% [markdown]
# # Coeval: xx,xy,xz comp

# %% [markdown]
# ## WST

# %%
simu00004_WST_yz = wst_op.apply(simu00004[0][0,:,:])
simu00004_WST_xz = wst_op.apply(simu00004[0][:,0,:])
simu00004_WST_xy = wst_op.apply(simu00004[0][:,:,0])

# %%
simu00004_WST_xy.plot_compare([simu00004_WST_xz,simu00004_WST_yz],layer = 1, labels = ['xy','xz','yz'])
plt.savefig(plt_dir+'WST_00004_direction_comp_S1.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
simu00004_WST_xy.plot_compare([simu00004_WST_xz,simu00004_WST_yz],layer = 2, labels = ['xy','xz','yz'])
plt.savefig(plt_dir+'WST_00004_direction_comp_S2.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="3000">

# %% [markdown]
# ## RWST

# %%
rwst_op = pw.RWSTOp(M, N, J, L, OS)

# %%
simu00004_RWST_yz = rwst_op.apply(simu00004[0][0,:,:])
simu00004_RWST_xz = rwst_op.apply(simu00004[0][:,0,:])
simu00004_RWST_xy = rwst_op.apply(simu00004[0][:,:,0])

# %%
simu00004_RWST_xy.plot_compare([simu00004_RWST_xz,simu00004_RWST_yz],names= ["S1Aniso", "ThetaRef1"],labels = ['xy', 'xz', 'yz'])
plt.savefig(plt_dir+'RWST_00004_direction_comp_S1_1.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
simu00004_RWST_xy.plot_compare([simu00004_RWST_xz,simu00004_RWST_yz],names= ["S1Iso"],labels = ['xy', 'xz', 'yz'])
plt.savefig(plt_dir+'RWST_00004_direction_comp_S1_2.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
simu00004_RWST_xy.plot_compare([simu00004_RWST_xz,simu00004_RWST_yz],names= ["S2Iso1", "S2Iso2"],labels = ['xy', 'xz', 'yz'])
plt.savefig(plt_dir+'RWST_00004_direction_comp_S2_1.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
simu00004_RWST_xy.plot_compare([simu00004_RWST_xz,simu00004_RWST_yz],names= ["S2Aniso1", "S2Aniso2"],labels = ['xy', 'xz', 'yz'])
plt.savefig(plt_dir+'RWST_00004_direction_comp_S2_2.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
simu00004_RWST_xy.plot_compare([simu00004_RWST_xz,simu00004_RWST_yz],names= ["ThetaRef2"],labels = ['xy', 'xz', 'yz'])
plt.savefig(plt_dir+'RWST_00004_direction_comp_S2_3.pdf' ,bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="400">
